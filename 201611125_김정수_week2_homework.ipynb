# %%
from urllib.parse import urlencode, quote_plus
import requests
import json
import xmltodict

# %%
url = "http://openapi-lib.sen.go.kr/openapi/service/lib/openApi"
my_key = "8107VbWaEhOG6C3lQPQORjhLXAP3z%2B8gbdHoZ1XY8NIjoxP3vgCuHH%2BLuYP9sIASx2uM6c1nneYhcq1TljaWyw%3D%3D"
class_key = "8Bx4C1%2Bbogiu3i0M5k7aqOf%2BTA5yCWK%2BFDI7nTSJ0oAhDj1NC5CtbI1TMgFmnpuZxJ9LBoCScqBhuw5sul2tmQ%3D%3D"

# %%
parameters = f'?{quote_plus("ServiceKey")}={class_key}&' + urlencode({
                "title":"파이썬", 
               "manageCd":"MA", 
               "numOfRows":20, 
               "pageNo":1})
print(parameters)
# Out:
# ?ServiceKey=8Bx4C1%2Bbogiu3i0M5k7aqOf%2BTA5yCWK%2BFDI7nTSJ0oAhDj1NC5CtbI1TMgFmnpuZxJ9LBoCScqBhuw5sul2tmQ%3D%3D&title=%ED%8C%8C%EC%9D%B4%EC%8D%AC&manageCd=MA&numOfRows=20&pageNo=1

# %%
response = requests.get(url + parameters)
print(url + parameters)
# Out:
# http://openapi-lib.sen.go.kr/openapi/service/lib/openApi?ServiceKey=8Bx4C1%2Bbogiu3i0M5k7aqOf%2BTA5yCWK%2BFDI7nTSJ0oAhDj1NC5CtbI1TMgFmnpuZxJ9LBoCScqBhuw5sul2tmQ%3D%3D&title=%ED%8C%8C%EC%9D%B4%EC%8D%AC&manageCd=MA&numOfRows=20&pageNo=1

# %%
with open("src/201611125_homework_week2.xml", "w", encoding="utf-8-sig") as f:
    f.write(response.text)

# %%
with open("src/201611125_homework_week2.xml",'r', encoding="utf-8-sig") as f:
    xmlString = f.read()
    
jsonString = json.dumps(xmltodict.parse(xmlString), indent=4, ensure_ascii=False)
 
with open("src/201611125_homework_week2.json", 'w', encoding="utf-8-sig") as f:
    f.write(jsonString)

# %%
# !cat "src/201611125_homework_week2.json"
# Out:
# ﻿{
#     "response": {
#         "header": {
#             "resultCode": "00",
#             "resultMsg": "NORMAL SERVICE."
#         },
#         "body": {
#             "items": {
#                 "item": [
#                     {
#                         "appendixYn": "N",
#                         "author": "사우랍 카푸 지음 ;김정중 옮김",
#                         "bookKey": "5387993273",
#                         "callNo": "005.133-ㅋ334ㅍ",
#                         "controlNo": "KMO201800317",
#                         "isbn": "9791161751061",
#                         "libName": "강남도서관",
#                         "manageCode": "MA",
#                         "pubYear": "2018",
#                         "publisher": "에이콘출판",
#                         "regNo": "EMA000257311",
#                         "rnum": "1",
#                         "shelfLocName": "[강남]4층 종합자료실",
#                         "speciesKey": "5387993271",
# ...
